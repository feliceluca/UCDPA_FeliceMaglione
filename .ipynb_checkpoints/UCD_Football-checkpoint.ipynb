# %%
import os 
import pandas as pd
file_path = os.getcwd() + '/Football_teams.csv'
df = pd.read_csv(file_path) # index_col = "Team"
df.head()
# Out:
#                   Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0      Manchester City  Premier League     83      15.8            46
# 1        Bayern Munich      Bundesliga     99      17.1            44
# 2  Paris Saint-Germain         Ligue 1     86      15.0            73
# 3            Barcelona          LaLiga     85      15.3            68
# 4          Real Madrid          LaLiga     67      14.4            57
#
#    red_cards  Possession%  Pass%  AerialsWon  Rating
# 0          2         60.8   89.4        12.8    7.01
# 1          3         58.1   85.5        12.9    6.95
# 2          7         60.1   89.5         9.5    6.88
# 3          2         62.4   89.7        10.6    6.87
# 4          2         57.7   87.7        11.8    6.86

# %%
# renaming column's name
df.rename(columns={'Shots pg' : 'Shots_pg',
                   'Possesion%': 'Possesion_perc',
                   'Pass%': 'Pass_perc'},
          inplace=True)

# converting names into lower case
df.columns = [col.lower() for col in df.columns]
print(df.columns)
# Out:
# Index(['team', 'tournament', 'goals', 'shots_pg', 'yellow_cards', 'red_cards',
#        'possession%', 'pass_perc', 'aerialswon', 'rating'],
#       dtype='object')

# %%
df.head()
# Out:
#                   team      tournament  goals  shots_pg  yellow_cards  \
# 0      Manchester City  Premier League     83      15.8            46
# 1        Bayern Munich      Bundesliga     99      17.1            44
# 2  Paris Saint-Germain         Ligue 1     86      15.0            73
# 3            Barcelona          LaLiga     85      15.3            68
# 4          Real Madrid          LaLiga     67      14.4            57
#
#    red_cards  possession%  pass_perc  aerialswon  rating
# 0          2         60.8       89.4        12.8    7.01
# 1          3         58.1       85.5        12.9    6.95
# 2          7         60.1       89.5         9.5    6.88
# 3          2         62.4       89.7        10.6    6.87
# 4          2         57.7       87.7        11.8    6.86

# %%
df.pivot (index = "team", columns = "tournament", values = "rating")

df2 = df.pivot (index = "team", columns = "tournament", values = "rating")

# %%
df["all_cards"] = df.apply(lambda x:x['yellow_cards'] + x['red_cards'], axis = 1)
df
# Out:
#                    team      tournament  goals  shots_pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# ..                  ...             ...    ...       ...           ...
# 93     Sheffield United  Premier League     20       8.5            73
# 94              Crotone         Serie A     45       9.5            85
# 95            Benevento         Serie A     40      11.0            90
# 96                Dijon         Ligue 1     25       9.2            75
# 97           Schalke 04      Bundesliga     25       8.9            70
#
#     red_cards  possession%  pass_perc  aerialswon  rating  all_cards
# 0           2         60.8       89.4        12.8    7.01         48
# 1           3         58.1       85.5        12.9    6.95         47
# 2           7         60.1       89.5         9.5    6.88         80
# 3           2         62.4       89.7        10.6    6.87         70
# 4           2         57.7       87.7        11.8    6.86         59
# ..        ...          ...        ...         ...     ...        ...
# 93          3         43.0       76.9        19.1    6.46         76
# 94          4         47.2       80.4        12.7    6.43         89
# 95          5         44.2       77.7        13.4    6.43         95
# 96          5         46.9       80.0        14.3    6.42         80
# 97          2         46.2       76.5        15.6    6.41         72
#
# [98 rows x 11 columns]

# %%
print(os.getcwd())
os.chdir('Documents/UCD_Phyton/UCD_Football')
print("Change to: ", os.getcwd())
# Out:
# /Users/luca
# Change to:  /Users/luca/Documents/UCD_Phyton/UCD_Football

# %%
def sum_cards(x,y):
    return x+y
df["all_cards"] = df.apply(lambda x: sum_cards (x = x['yellow_cards'], y = x['red_cards']), axis = 1)
df
# Out:
#                    team      tournament  goals  shots_pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# ..                  ...             ...    ...       ...           ...
# 93     Sheffield United  Premier League     20       8.5            73
# 94              Crotone         Serie A     45       9.5            85
# 95            Benevento         Serie A     40      11.0            90
# 96                Dijon         Ligue 1     25       9.2            75
# 97           Schalke 04      Bundesliga     25       8.9            70
#
#     red_cards  possession%  pass_perc  aerialswon  rating  all_cards
# 0           2         60.8       89.4        12.8    7.01         48
# 1           3         58.1       85.5        12.9    6.95         47
# 2           7         60.1       89.5         9.5    6.88         80
# 3           2         62.4       89.7        10.6    6.87         70
# 4           2         57.7       87.7        11.8    6.86         59
# ..        ...          ...        ...         ...     ...        ...
# 93          3         43.0       76.9        19.1    6.46         76
# 94          4         47.2       80.4        12.7    6.43         89
# 95          5         44.2       77.7        13.4    6.43         95
# 96          5         46.9       80.0        14.3    6.42         80
# 97          2         46.2       76.5        15.6    6.41         72
#
# [98 rows x 11 columns]

# %%
[ sum_cards(x['yellow_cards'], x['red_cards']) for x in df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c449b3312e0f> in <module>
# ----> 1 [ sum_cards(x['yellow_cards'], x['red_cards']) for x in df]
#
# <ipython-input-28-c449b3312e0f> in <listcomp>(.0)
# ----> 1 [ sum_cards(x['yellow_cards'], x['red_cards']) for x in df]
#
# TypeError: string indices must be integers

# %%
[x for x in df.iterrows()]
# Out:
# [(0,
#   team            Manchester City
#   tournament       Premier League
#   goals                        83
#   shots_pg                   15.8
#   yellow_cards                 46
#   red_cards                     2
#   possession%                60.8
#   pass_perc                  89.4
#   aerialswon                 12.8
#   rating                     7.01
#   all_cards                    48
#   Name: 0, dtype: object),
#  (1,
#   team            Bayern Munich
#   tournament         Bundesliga
#   goals                      99
#   shots_pg                 17.1
#   yellow_cards               44
#   red_cards                   3
#   possession%              58.1
#   pass_perc                85.5
#   aerialswon               12.9
#   rating                   6.95
#   all_cards                  47
#   Name: 1, dtype: object),
#  (2,
#   team            Paris Saint-Germain
#   tournament                  Ligue 1
#   goals                            86
#   shots_pg                       15.0
#   yellow_cards                     73
#   red_cards                         7
#   possession%                    60.1
#   pass_perc                      89.5
#   aerialswon                      9.5
#   rating                         6.88
#   all_cards                        80
#   Name: 2, dtype: object),
#  (3,
#   team            Barcelona
#   tournament         LaLiga
#   goals                  85
#   shots_pg             15.3
#   yellow_cards           68
#   red_cards               2
#   possession%          62.4
#   pass_perc            89.7
#   aerialswon           10.6
#   rating               6.87
#   all_cards              70
#   Name: 3, dtype: object),
#  (4,
#   team            Real Madrid
#   tournament           LaLiga
#   goals                    67
#   shots_pg               14.4
#   yellow_cards             57
#   red_cards                 2
#   possession%            57.7
#   pass_perc              87.7
#   aerialswon             11.8
#   rating                 6.86
#   all_cards                59
#   Name: 4, dtype: object),
#  (5,
#   team            Manchester United
#   tournament         Premier League
#   goals                          73
#   shots_pg                     13.8
#   yellow_cards                   64
#   red_cards                       1
#   possession%                  54.5
#   pass_perc                    84.8
#   aerialswon                   14.5
#   rating                       6.85
#   all_cards                      65
#   Name: 5, dtype: object),
#  (6,
#   team            Juventus
#   tournament       Serie A
#   goals                 77
#   shots_pg            15.7
#   yellow_cards          76
#   red_cards              6
#   possession%         55.4
#   pass_perc           88.3
#   aerialswon          11.4
#   rating              6.85
#   all_cards             82
#   Name: 6, dtype: object),
#  (7,
#   team               Aston Villa
#   tournament      Premier League
#   goals                       55
#   shots_pg                  13.7
#   yellow_cards                63
#   red_cards                    4
#   possession%               49.1
#   pass_perc                 78.6
#   aerialswon                19.4
#   rating                    6.84
#   all_cards                   67
#   Name: 7, dtype: object),
#  (8,
#   team            Borussia Dortmund
#   tournament             Bundesliga
#   goals                          75
#   shots_pg                     14.6
#   yellow_cards                   43
#   red_cards                       1
#   possession%                  57.5
#   pass_perc                    85.5
#   aerialswon                   12.8
#   rating                       6.84
#   all_cards                      44
#   Name: 8, dtype: object),
#  (9,
#   team            Atletico Madrid
#   tournament               LaLiga
#   goals                        67
#   shots_pg                   12.1
#   yellow_cards                100
#   red_cards                     0
#   possession%                51.8
#   pass_perc                  83.1
#   aerialswon                 14.4
#   rating                     6.84
#   all_cards                   100
#   Name: 9, dtype: object),
#  (10,
#   team            Atalanta
#   tournament       Serie A
#   goals                 90
#   shots_pg            16.3
#   yellow_cards          66
#   red_cards              3
#   possession%         53.5
#   pass_perc           83.5
#   aerialswon          16.8
#   rating              6.84
#   all_cards             69
#   Name: 10, dtype: object),
#  (11,
#   team                   Chelsea
#   tournament      Premier League
#   goals                       58
#   shots_pg                  14.6
#   yellow_cards                49
#   red_cards                    3
#   possession%               58.6
#   pass_perc                 87.0
#   aerialswon                15.2
#   rating                    6.83
#   all_cards                   52
#   Name: 11, dtype: object),
#  (12,
#   team                 Liverpool
#   tournament      Premier League
#   goals                       68
#   shots_pg                  16.0
#   yellow_cards                40
#   red_cards                    0
#   possession%               59.0
#   pass_perc                 85.7
#   aerialswon                14.3
#   rating                    6.82
#   all_cards                   40
#   Name: 12, dtype: object),
#  (13,
#   team            AC Milan
#   tournament       Serie A
#   goals                 74
#   shots_pg            14.7
#   yellow_cards          80
#   red_cards              4
#   possession%         51.4
#   pass_perc           84.0
#   aerialswon          15.2
#   rating              6.82
#   all_cards             84
#   Name: 13, dtype: object),
#  (14,
#   team              Lille
#   tournament      Ligue 1
#   goals                64
#   shots_pg           12.8
#   yellow_cards         67
#   red_cards             2
#   possession%        52.6
#   pass_perc          83.5
#   aerialswon         15.8
#   rating             6.82
#   all_cards            69
#   Name: 14, dtype: object),
#  (15,
#   team                 Tottenham
#   tournament      Premier League
#   goals                       68
#   shots_pg                  11.7
#   yellow_cards                53
#   red_cards                    2
#   possession%               51.3
#   pass_perc                 81.8
#   aerialswon                16.4
#   rating                    6.81
#   all_cards                   55
#   Name: 15, dtype: object),
#  (16,
#   team             Napoli
#   tournament      Serie A
#   goals                86
#   shots_pg           17.0
#   yellow_cards         71
#   red_cards             3
#   possession%        54.1
#   pass_perc          87.0
#   aerialswon         11.1
#   rating             6.81
#   all_cards            74
#   Name: 16, dtype: object),
#  (17,
#   team                 Leicester
#   tournament      Premier League
#   goals                       68
#   shots_pg                  12.8
#   yellow_cards                61
#   red_cards                    0
#   possession%               53.2
#   pass_perc                 82.1
#   aerialswon                16.2
#   rating                     6.8
#   all_cards                   61
#   Name: 17, dtype: object),
#  (18,
#   team             Wolfsburg
#   tournament      Bundesliga
#   goals                   61
#   shots_pg              14.1
#   yellow_cards            56
#   red_cards                3
#   possession%           51.0
#   pass_perc             78.0
#   aerialswon            16.9
#   rating                 6.8
#   all_cards               59
#   Name: 18, dtype: object),
#  (19,
#   team              Inter
#   tournament      Serie A
#   goals                89
#   shots_pg           14.5
#   yellow_cards         59
#   red_cards             2
#   possession%        52.0
#   pass_perc          87.0
#   aerialswon         11.8
#   rating              6.8
#   all_cards            61
#   Name: 19, dtype: object),
#  (20,
#   team               Lyon
#   tournament      Ligue 1
#   goals                81
#   shots_pg           16.1
#   yellow_cards         60
#   red_cards            10
#   possession%        53.6
#   pass_perc          84.7
#   aerialswon         14.3
#   rating              6.8
#   all_cards            70
#   Name: 20, dtype: object),
#  (21,
#   team            RB Leipzig
#   tournament      Bundesliga
#   goals                   60
#   shots_pg              16.0
#   yellow_cards            57
#   red_cards                0
#   possession%           57.3
#   pass_perc             83.2
#   aerialswon            18.6
#   rating                6.78
#   all_cards               57
#   Name: 21, dtype: object),
#  (22,
#   team                     Leeds
#   tournament      Premier League
#   goals                       62
#   shots_pg                  13.7
#   yellow_cards                61
#   red_cards                    1
#   possession%               55.1
#   pass_perc                 80.8
#   aerialswon                14.5
#   rating                    6.77
#   all_cards                   62
#   Name: 22, dtype: object),
#  (23,
#   team                  West Ham
#   tournament      Premier League
#   goals                       62
#   shots_pg                  12.3
#   yellow_cards                48
#   red_cards                    3
#   possession%               44.5
#   pass_perc                 77.8
#   aerialswon                19.9
#   rating                    6.77
#   all_cards                   51
#   Name: 23, dtype: object),
#  (24,
#   team                   Everton
#   tournament      Premier League
#   goals                       47
#   shots_pg                  10.5
#   yellow_cards                59
#   red_cards                    2
#   possession%               47.3
#   pass_perc                 81.4
#   aerialswon                17.7
#   rating                    6.73
#   all_cards                   61
#   Name: 24, dtype: object),
#  (25,
#   team            Bayer Leverkusen
#   tournament            Bundesliga
#   goals                         53
#   shots_pg                    13.0
#   yellow_cards                  58
#   red_cards                      0
#   possession%                 57.3
#   pass_perc                   84.4
#   aerialswon                  13.1
#   rating                      6.73
#   all_cards                     58
#   Name: 25, dtype: object),
#  (26,
#   team            Eintracht Frankfurt
#   tournament               Bundesliga
#   goals                            69
#   shots_pg                       13.2
#   yellow_cards                     80
#   red_cards                         1
#   possession%                    52.4
#   pass_perc                      79.6
#   aerialswon                     17.9
#   rating                         6.73
#   all_cards                        81
#   Name: 26, dtype: object),
#  (27,
#   team             Monaco
#   tournament      Ligue 1
#   goals                76
#   shots_pg           12.8
#   yellow_cards         74
#   red_cards             7
#   possession%        54.2
#   pass_perc          82.7
#   aerialswon         16.5
#   rating             6.73
#   all_cards            81
#   Name: 27, dtype: object),
#  (28,
#   team               Roma
#   tournament      Serie A
#   goals                68
#   shots_pg           14.3
#   yellow_cards         84
#   red_cards             3
#   possession%        51.5
#   pass_perc          84.5
#   aerialswon         12.1
#   rating             6.71
#   all_cards            87
#   Name: 28, dtype: object),
#  (29,
#   team            Sevilla
#   tournament       LaLiga
#   goals                53
#   shots_pg           12.1
#   yellow_cards         75
#   red_cards             2
#   possession%        58.7
#   pass_perc          86.2
#   aerialswon         16.6
#   rating              6.7
#   all_cards            77
#   Name: 29, dtype: object),
#  (30,
#   team            Borussia M.Gladbach
#   tournament               Bundesliga
#   goals                            64
#   shots_pg                       13.4
#   yellow_cards                     61
#   red_cards                         2
#   possession%                    51.5
#   pass_perc                      82.0
#   aerialswon                     15.3
#   rating                          6.7
#   all_cards                        63
#   Name: 30, dtype: object),
#  (31,
#   team                   Arsenal
#   tournament      Premier League
#   goals                       55
#   shots_pg                  12.1
#   yellow_cards                47
#   red_cards                    5
#   possession%               52.7
#   pass_perc                 85.0
#   aerialswon                13.5
#   rating                    6.69
#   all_cards                   52
#   Name: 31, dtype: object),
#  (32,
#   team             Rennes
#   tournament      Ligue 1
#   goals                52
#   shots_pg           13.5
#   yellow_cards         80
#   red_cards             5
#   possession%        56.8
#   pass_perc          85.6
#   aerialswon         16.9
#   rating             6.69
#   all_cards            85
#   Name: 32, dtype: object),
#  (33,
#   team            VfB Stuttgart
#   tournament         Bundesliga
#   goals                      56
#   shots_pg                 13.4
#   yellow_cards               63
#   red_cards                   2
#   possession%              51.5
#   pass_perc                81.1
#   aerialswon               16.3
#   rating                   6.68
#   all_cards                  65
#   Name: 33, dtype: object),
#  (34,
#   team            Wolverhampton Wanderers
#   tournament               Premier League
#   goals                                36
#   shots_pg                           12.2
#   yellow_cards                         53
#   red_cards                             1
#   possession%                        49.7
#   pass_perc                          83.2
#   aerialswon                         15.3
#   rating                             6.67
#   all_cards                            54
#   Name: 34, dtype: object),
#  (35,
#   team            Sassuolo
#   tournament       Serie A
#   goals                 64
#   shots_pg            13.9
#   yellow_cards          74
#   red_cards              4
#   possession%         58.2
#   pass_perc           87.8
#   aerialswon          10.9
#   rating              6.67
#   all_cards             78
#   Name: 35, dtype: object),
#  (36,
#   team               Metz
#   tournament      Ligue 1
#   goals                44
#   shots_pg           11.5
#   yellow_cards         82
#   red_cards             4
#   possession%        46.9
#   pass_perc          79.8
#   aerialswon         16.1
#   rating             6.66
#   all_cards            86
#   Name: 36, dtype: object),
#  (37,
#   team            Villarreal
#   tournament          LaLiga
#   goals                   60
#   shots_pg              10.7
#   yellow_cards            65
#   red_cards                5
#   possession%           54.3
#   pass_perc             84.4
#   aerialswon            13.0
#   rating                6.66
#   all_cards               70
#   Name: 37, dtype: object),
#  (38,
#   team            Real Sociedad
#   tournament             LaLiga
#   goals                      59
#   shots_pg                 11.3
#   yellow_cards               81
#   red_cards                   1
#   possession%              53.7
#   pass_perc                80.8
#   aerialswon               17.9
#   rating                   6.65
#   all_cards                  82
#   Name: 38, dtype: object),
#  (39,
#   team                  Brighton
#   tournament      Premier League
#   goals                       40
#   shots_pg                  12.8
#   yellow_cards                45
#   red_cards                    6
#   possession%               50.7
#   pass_perc                 81.3
#   aerialswon                14.2
#   rating                    6.65
#   all_cards                   51
#   Name: 39, dtype: object),
#  (40,
#   team            Real Betis
#   tournament          LaLiga
#   goals                   50
#   shots_pg              11.7
#   yellow_cards            87
#   red_cards                8
#   possession%           52.9
#   pass_perc             82.0
#   aerialswon            16.4
#   rating                6.64
#   all_cards               95
#   Name: 40, dtype: object),
#  (41,
#   team                   Burnley
#   tournament      Premier League
#   goals                       33
#   shots_pg                  10.1
#   yellow_cards                48
#   red_cards                    0
#   possession%               43.5
#   pass_perc                 71.6
#   aerialswon                23.4
#   rating                    6.64
#   all_cards                   48
#   Name: 41, dtype: object),
#  (42,
#   team               Lens
#   tournament      Ligue 1
#   goals                55
#   shots_pg           11.7
#   yellow_cards         84
#   red_cards             7
#   possession%        51.1
#   pass_perc          81.8
#   aerialswon         17.4
#   rating             6.64
#   all_cards            91
#   Name: 42, dtype: object),
#  (43,
#   team              Brest
#   tournament      Ligue 1
#   goals                50
#   shots_pg           11.8
#   yellow_cards         60
#   red_cards             4
#   possession%        49.4
#   pass_perc          81.3
#   aerialswon         18.6
#   rating             6.64
#   all_cards            64
#   Name: 43, dtype: object),
#  (44,
#   team                    Fulham
#   tournament      Premier League
#   goals                       27
#   shots_pg                  11.6
#   yellow_cards                67
#   red_cards                    3
#   possession%               50.0
#   pass_perc                 81.2
#   aerialswon                17.2
#   rating                    6.63
#   all_cards                   70
#   Name: 44, dtype: object),
#  (45,
#   team            Marseille
#   tournament        Ligue 1
#   goals                  54
#   shots_pg             10.0
#   yellow_cards           94
#   red_cards               9
#   possession%          52.4
#   pass_perc            82.0
#   aerialswon           14.9
#   rating               6.63
#   all_cards             103
#   Name: 45, dtype: object),
#  (46,
#   team            Sampdoria
#   tournament        Serie A
#   goals                  52
#   shots_pg             11.3
#   yellow_cards           81
#   red_cards               3
#   possession%          46.1
#   pass_perc            78.5
#   aerialswon           16.8
#   rating               6.63
#   all_cards              84
#   Name: 46, dtype: object),
#  (47,
#   team            Montpellier
#   tournament          Ligue 1
#   goals                    60
#   shots_pg               12.2
#   yellow_cards             65
#   red_cards                 7
#   possession%            46.4
#   pass_perc              78.8
#   aerialswon             17.9
#   rating                 6.63
#   all_cards                72
#   Name: 47, dtype: object),
#  (48,
#   team               Nice
#   tournament      Ligue 1
#   goals                50
#   shots_pg           10.8
#   yellow_cards         69
#   red_cards             4
#   possession%        53.4
#   pass_perc          85.6
#   aerialswon         10.5
#   rating             6.63
#   all_cards            73
#   Name: 48, dtype: object),
#  (49,
#   team            Hoffenheim
#   tournament      Bundesliga
#   goals                   52
#   shots_pg              12.6
#   yellow_cards            65
#   red_cards                4
#   possession%           50.8
#   pass_perc             80.7
#   aerialswon            15.7
#   rating                6.63
#   all_cards               69
#   Name: 49, dtype: object),
#  (50,
#   team               Southampton
#   tournament      Premier League
#   goals                       47
#   shots_pg                  11.2
#   yellow_cards                52
#   red_cards                    3
#   possession%               51.4
#   pass_perc                 79.3
#   aerialswon                14.1
#   rating                    6.62
#   all_cards                   55
#   Name: 50, dtype: object),
#  (51,
#   team            Newcastle United
#   tournament        Premier League
#   goals                         46
#   shots_pg                    10.4
#   yellow_cards                  61
#   red_cards                      3
#   possession%                 41.6
#   pass_perc                   76.0
#   aerialswon                  17.1
#   rating                      6.62
#   all_cards                     64
#   Name: 51, dtype: object),
#  (52,
#   team              Lazio
#   tournament      Serie A
#   goals                61
#   shots_pg           13.8
#   yellow_cards        100
#   red_cards             5
#   possession%        52.2
#   pass_perc          83.8
#   aerialswon         14.6
#   rating             6.62
#   all_cards           105
#   Name: 52, dtype: object),
#  (53,
#   team             Nantes
#   tournament      Ligue 1
#   goals                47
#   shots_pg           10.8
#   yellow_cards         68
#   red_cards             4
#   possession%        45.2
#   pass_perc          77.0
#   aerialswon         18.1
#   rating             6.62
#   all_cards            72
#   Name: 53, dtype: object),
#  (54,
#   team            Union Berlin
#   tournament        Bundesliga
#   goals                     50
#   shots_pg                11.7
#   yellow_cards              55
#   red_cards                  2
#   possession%             45.9
#   pass_perc               76.2
#   aerialswon              17.6
#   rating                  6.62
#   all_cards                 57
#   Name: 54, dtype: object),
#  (55,
#   team            Strasbourg
#   tournament         Ligue 1
#   goals                   49
#   shots_pg              11.3
#   yellow_cards            56
#   red_cards                3
#   possession%           46.5
#   pass_perc             78.3
#   aerialswon            18.3
#   rating                6.61
#   all_cards               59
#   Name: 55, dtype: object),
#  (56,
#   team            Crystal Palace
#   tournament      Premier League
#   goals                       41
#   shots_pg                   9.2
#   yellow_cards                54
#   red_cards                    2
#   possession%               42.9
#   pass_perc                 76.1
#   aerialswon                18.3
#   rating                    6.61
#   all_cards                   56
#   Name: 56, dtype: object),
#  (57,
#   team              Freiburg
#   tournament      Bundesliga
#   goals                   52
#   shots_pg              11.4
#   yellow_cards            63
#   red_cards                0
#   possession%           47.5
#   pass_perc             78.1
#   aerialswon            17.5
#   rating                 6.6
#   all_cards               63
#   Name: 57, dtype: object),
#  (58,
#   team            Valencia
#   tournament        LaLiga
#   goals                 50
#   shots_pg            10.3
#   yellow_cards          77
#   red_cards              5
#   possession%         47.9
#   pass_perc           79.4
#   aerialswon          16.3
#   rating               6.6
#   all_cards             82
#   Name: 58, dtype: object),
#  (59,
#   team            Celta Vigo
#   tournament          LaLiga
#   goals                   55
#   shots_pg               9.4
#   yellow_cards           104
#   red_cards                5
#   possession%           52.0
#   pass_perc             79.9
#   aerialswon            16.5
#   rating                 6.6
#   all_cards              109
#   Name: 59, dtype: object),
#  (60,
#   team              Reims
#   tournament      Ligue 1
#   goals                42
#   shots_pg            9.6
#   yellow_cards         75
#   red_cards             8
#   possession%        46.3
#   pass_perc          80.7
#   aerialswon         13.4
#   rating              6.6
#   all_cards            83
#   Name: 60, dtype: object),
#  (61,
#   team             Torino
#   tournament      Serie A
#   goals                50
#   shots_pg           12.2
#   yellow_cards         72
#   red_cards             4
#   possession%        48.0
#   pass_perc          80.5
#   aerialswon         16.1
#   rating             6.59
#   all_cards            76
#   Name: 61, dtype: object),
#  (62,
#   team             Verona
#   tournament      Serie A
#   goals                43
#   shots_pg           10.6
#   yellow_cards         91
#   red_cards             1
#   possession%        49.6
#   pass_perc          76.3
#   aerialswon         20.6
#   rating             6.59
#   all_cards            92
#   Name: 62, dtype: object),
#  (63,
#   team            Saint-Etienne
#   tournament            Ligue 1
#   goals                      42
#   shots_pg                 11.6
#   yellow_cards               76
#   red_cards                   2
#   possession%              49.0
#   pass_perc                79.3
#   aerialswon               16.4
#   rating                   6.59
#   all_cards                  78
#   Name: 63, dtype: object),
#  (64,
#   team            Bordeaux
#   tournament       Ligue 1
#   goals                 42
#   shots_pg            11.1
#   yellow_cards          74
#   red_cards              4
#   possession%         50.2
#   pass_perc           83.3
#   aerialswon          15.4
#   rating              6.59
#   all_cards             78
#   Name: 64, dtype: object),
#  (65,
#   team            Hertha Berlin
#   tournament         Bundesliga
#   goals                      41
#   shots_pg                 11.3
#   yellow_cards               63
#   red_cards                   3
#   possession%              49.8
#   pass_perc                79.5
#   aerialswon               15.8
#   rating                   6.58
#   all_cards                  66
#   Name: 65, dtype: object),
#  (66,
#   team            Cagliari
#   tournament       Serie A
#   goals                 43
#   shots_pg            11.4
#   yellow_cards          73
#   red_cards              3
#   possession%         45.8
#   pass_perc           79.8
#   aerialswon          17.2
#   rating              6.58
#   all_cards             76
#   Name: 66, dtype: object),
#  (67,
#   team              Mainz 05
#   tournament      Bundesliga
#   goals                   39
#   shots_pg              11.1
#   yellow_cards            61
#   red_cards                1
#   possession%           42.7
#   pass_perc             71.3
#   aerialswon            18.3
#   rating                6.57
#   all_cards               62
#   Name: 67, dtype: object),
#  (68,
#   team            Bologna
#   tournament      Serie A
#   goals                51
#   shots_pg           13.1
#   yellow_cards         78
#   red_cards             4
#   possession%        50.7
#   pass_perc          81.5
#   aerialswon         15.1
#   rating             6.56
#   all_cards            82
#   Name: 68, dtype: object),
#  (69,
#   team              Augsburg
#   tournament      Bundesliga
#   goals                   36
#   shots_pg               9.9
#   yellow_cards            65
#   red_cards                4
#   possession%           44.0
#   pass_perc             73.6
#   aerialswon            16.8
#   rating                6.56
#   all_cards               69
#   Name: 69, dtype: object),
#  (70,
#   team            Udinese
#   tournament      Serie A
#   goals                42
#   shots_pg           10.9
#   yellow_cards         63
#   red_cards             2
#   possession%        47.2
#   pass_perc          82.5
#   aerialswon         13.1
#   rating             6.55
#   all_cards            65
#   Name: 70, dtype: object),
#  (71,
#   team            SD Huesca
#   tournament         LaLiga
#   goals                  34
#   shots_pg             10.7
#   yellow_cards           68
#   red_cards               2
#   possession%          48.7
#   pass_perc            79.8
#   aerialswon           15.7
#   rating               6.55
#   all_cards              70
#   Name: 71, dtype: object),
#  (72,
#   team            Athletic Bilbao
#   tournament               LaLiga
#   goals                        46
#   shots_pg                   10.6
#   yellow_cards                 81
#   red_cards                     3
#   possession%                49.4
#   pass_perc                  78.5
#   aerialswon                 17.9
#   rating                     6.54
#   all_cards                    84
#   Name: 72, dtype: object),
#  (73,
#   team            Osasuna
#   tournament       LaLiga
#   goals                37
#   shots_pg            9.8
#   yellow_cards         74
#   red_cards             5
#   possession%        44.6
#   pass_perc          70.2
#   aerialswon         26.8
#   rating             6.54
#   all_cards            79
#   Name: 73, dtype: object),
#  (74,
#   team            Lorient
#   tournament      Ligue 1
#   goals                50
#   shots_pg           11.2
#   yellow_cards         67
#   red_cards             3
#   possession%        45.9
#   pass_perc          78.8
#   aerialswon         13.7
#   rating             6.54
#   all_cards            70
#   Name: 74, dtype: object),
#  (75,
#   team              Genoa
#   tournament      Serie A
#   goals                47
#   shots_pg            9.0
#   yellow_cards         85
#   red_cards             2
#   possession%        46.1
#   pass_perc          79.7
#   aerialswon         13.7
#   rating             6.54
#   all_cards            87
#   Name: 75, dtype: object),
#  (76,
#   team            Arminia Bielefeld
#   tournament             Bundesliga
#   goals                          26
#   shots_pg                      9.8
#   yellow_cards                   52
#   red_cards                       1
#   possession%                  44.1
#   pass_perc                    74.6
#   aerialswon                   22.2
#   rating                       6.53
#   all_cards                      53
#   Name: 76, dtype: object),
#  (77,
#   team             Angers
#   tournament      Ligue 1
#   goals                40
#   shots_pg           10.7
#   yellow_cards         63
#   red_cards             2
#   possession%        47.1
#   pass_perc          81.3
#   aerialswon         13.2
#   rating             6.53
#   all_cards            65
#   Name: 77, dtype: object),
#  (78,
#   team             Eibar
#   tournament      LaLiga
#   goals               29
#   shots_pg          11.9
#   yellow_cards        67
#   red_cards            3
#   possession%       49.2
#   pass_perc         72.6
#   aerialswon        24.4
#   rating            6.53
#   all_cards           70
#   Name: 78, dtype: object),
#  (79,
#   team            Werder Bremen
#   tournament         Bundesliga
#   goals                      36
#   shots_pg                 10.6
#   yellow_cards               63
#   red_cards                   3
#   possession%              45.2
#   pass_perc                76.2
#   aerialswon               18.3
#   rating                   6.52
#   all_cards                  66
#   Name: 79, dtype: object),
#  (80,
#   team            Fiorentina
#   tournament         Serie A
#   goals                   47
#   shots_pg               9.8
#   yellow_cards            86
#   red_cards                5
#   possession%           46.8
#   pass_perc             81.0
#   aerialswon            14.2
#   rating                6.52
#   all_cards               91
#   Name: 80, dtype: object),
#  (81,
#   team              Nimes
#   tournament      Ligue 1
#   goals                40
#   shots_pg           10.3
#   yellow_cards         57
#   red_cards             5
#   possession%        45.8
#   pass_perc          77.5
#   aerialswon         14.0
#   rating             6.52
#   all_cards            62
#   Name: 81, dtype: object),
#  (82,
#   team            West Bromwich Albion
#   tournament            Premier League
#   goals                             35
#   shots_pg                         8.9
#   yellow_cards                      51
#   red_cards                          4
#   possession%                     41.0
#   pass_perc                       72.2
#   aerialswon                      19.1
#   rating                          6.51
#   all_cards                         55
#   Name: 82, dtype: object),
#  (83,
#   team               FC Koln
#   tournament      Bundesliga
#   goals                   34
#   shots_pg              10.6
#   yellow_cards            62
#   red_cards                1
#   possession%           47.1
#   pass_perc             77.3
#   aerialswon            18.5
#   rating                6.51
#   all_cards               63
#   Name: 83, dtype: object),
#  (84,
#   team            Deportivo Alaves
#   tournament                LaLiga
#   goals                         36
#   shots_pg                     9.1
#   yellow_cards                  87
#   red_cards                      8
#   possession%                 44.6
#   pass_perc                   72.9
#   aerialswon                  22.6
#   rating                       6.5
#   all_cards                     95
#   Name: 84, dtype: object),
#  (85,
#   team            Levante
#   tournament       LaLiga
#   goals                46
#   shots_pg           10.1
#   yellow_cards         70
#   red_cards             1
#   possession%        51.5
#   pass_perc          80.1
#   aerialswon         12.2
#   rating              6.5
#   all_cards            71
#   Name: 85, dtype: object),
#  (86,
#   team             Spezia
#   tournament      Serie A
#   goals                52
#   shots_pg           10.2
#   yellow_cards         92
#   red_cards             5
#   possession%        51.6
#   pass_perc          81.1
#   aerialswon         14.4
#   rating              6.5
#   all_cards            97
#   Name: 86, dtype: object),
#  (87,
#   team            Getafe
#   tournament      LaLiga
#   goals               28
#   shots_pg           9.5
#   yellow_cards       117
#   red_cards            7
#   possession%       44.4
#   pass_perc         66.5
#   aerialswon        22.8
#   rating            6.49
#   all_cards          124
#   Name: 87, dtype: object),
#  (88,
#   team            Parma Calcio 1913
#   tournament                Serie A
#   goals                          39
#   shots_pg                     10.4
#   yellow_cards                   91
#   red_cards                       1
#   possession%                  48.4
#   pass_perc                    82.5
#   aerialswon                   16.9
#   rating                       6.49
#   all_cards                      92
#   Name: 88, dtype: object),
#  (89,
#   team             Elche
#   tournament      LaLiga
#   goals               34
#   shots_pg           7.1
#   yellow_cards        95
#   red_cards            3
#   possession%       48.1
#   pass_perc         81.5
#   aerialswon        13.2
#   rating            6.48
#   all_cards           98
#   Name: 89, dtype: object),
#  (90,
#   team            Granada
#   tournament       LaLiga
#   goals                47
#   shots_pg            9.4
#   yellow_cards         96
#   red_cards             6
#   possession%        43.4
#   pass_perc          70.0
#   aerialswon         18.3
#   rating             6.47
#   all_cards           102
#   Name: 90, dtype: object),
#  (91,
#   team             Cadiz
#   tournament      LaLiga
#   goals               36
#   shots_pg           8.0
#   yellow_cards        77
#   red_cards            3
#   possession%       38.5
#   pass_perc         68.8
#   aerialswon        18.5
#   rating            6.47
#   all_cards           80
#   Name: 91, dtype: object),
#  (92,
#   team            Real Valladolid
#   tournament               LaLiga
#   goals                        34
#   shots_pg                    9.7
#   yellow_cards                 93
#   red_cards                     4
#   possession%                46.2
#   pass_perc                  74.8
#   aerialswon                 17.1
#   rating                     6.46
#   all_cards                    97
#   Name: 92, dtype: object),
#  (93,
#   team            Sheffield United
#   tournament        Premier League
#   goals                         20
#   shots_pg                     8.5
#   yellow_cards                  73
#   red_cards                      3
#   possession%                 43.0
#   pass_perc                   76.9
#   aerialswon                  19.1
#   rating                      6.46
#   all_cards                     76
#   Name: 93, dtype: object),
#  (94,
#   team            Crotone
#   tournament      Serie A
#   goals                45
#   shots_pg            9.5
#   yellow_cards         85
#   red_cards             4
#   possession%        47.2
#   pass_perc          80.4
#   aerialswon         12.7
#   rating             6.43
#   all_cards            89
#   Name: 94, dtype: object),
#  (95,
#   team            Benevento
#   tournament        Serie A
#   goals                  40
#   shots_pg             11.0
#   yellow_cards           90
#   red_cards               5
#   possession%          44.2
#   pass_perc            77.7
#   aerialswon           13.4
#   rating               6.43
#   all_cards              95
#   Name: 95, dtype: object),
#  (96,
#   team              Dijon
#   tournament      Ligue 1
#   goals                25
#   shots_pg            9.2
#   yellow_cards         75
#   red_cards             5
#   possession%        46.9
#   pass_perc          80.0
#   aerialswon         14.3
#   rating             6.42
#   all_cards            80
#   Name: 96, dtype: object),
#  (97,
#   team            Schalke 04
#   tournament      Bundesliga
#   goals                   25
#   shots_pg               8.9
#   yellow_cards            70
#   red_cards                2
#   possession%           46.2
#   pass_perc             76.5
#   aerialswon            15.6
#   rating                6.41
#   all_cards               72
#   Name: 97, dtype: object)]

# %%
# Out:
# <generator object DataFrame.iterrows at 0x7fb6f6baa430>
